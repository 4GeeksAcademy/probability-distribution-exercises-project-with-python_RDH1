# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom, norm, uniform

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result



# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %%
# Funciones para distribuciones normales:

def dnorm(x, mean = 0, desv = 1):
    """
    Calcula la estimación puntual de la distribución normal.
    """
    result = norm.pdf(x, loc = mean, scale = desv)

    return result

def pnorm(x_range, mean = 0, desv = 1):
    """
    Calcula el acumulado de la distribución normal.
    """
    result = norm.cdf(x_range, loc = mean, scale = desv)

    return result

def qnorm(p, mean = 0, desv = 1):
    """
    Calcula la función cuantil a partir de la distribución normal.
    """
    result = norm.ppf(p, loc = mean, scale = desv)

    return result

def rnorm(n, mean = 0, desv = 1):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(loc = mean, scale = desv, size = n)

    return result

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

mean = 0
desv = 1
data = np.arange(-10, 10, 0.01)

pdf = dnorm(data, mean = mean, desv = desv) # densidad de probabilidad
cdf = pnorm(data, mean = mean, desv = desv) # distribución acumulada
ppf = qnorm(data, mean = mean, desv = desv) # percentiles / cuantiles

fig, axis = plt.subplots(3, 1, figsize = (6, 10))

axis[0].plot(data, pdf, color = "orange")
axis[1].plot(data, cdf, color = "black")
axis[2].plot(data, ppf, color = "purple")

plt.tight_layout()
plt.show()

# %%
#Funciones para distribución uniforme: 

def dunif(x, lower = 0, upper = 1):
    """
    Calcula la estimación puntual de la distribución uniforme.
    """
    result = uniform.pdf(x, loc = lower, scale = upper - lower)
    return result

def punif(q, lower = 0, upper = 1):
    """
    Calcula el acumulado de la distribución uniforme.
    """
    result = uniform.cdf(q, loc = lower, scale = upper - lower)
    return result

def qunif(p, lower = 0, upper = 1):
    """
    Calcula la función cuantil a partir de la distribución uniforme.
    """
    result = uniform.ppf(p, loc = lower, scale = upper - lower)
    return result

def runif(n, lower = 0, upper = 1):
    """
    Genera variables aleatorias a partir de la distribución uniforme.
    """
    result = uniform.rvs(loc = lower, scale = upper - lower, size = n)
    return result

# %%
# Método de graficación de distribución uniforme. 

np.random.seed(42)

lower = 0
upper = 1
data = np.arange(-10, 10, 0.01)

pmf1 = dunif(data, lower = lower, upper = upper)
cdf1 = punif(data, lower = lower, upper = upper)
ppf1 = qunif(data, lower = lower, upper = upper)

fig, axis = plt.subplots(3, 1, figsize = (8, 10))

axis[0].plot(data, pmf1, color = "green")
axis[1].plot(data, cdf1, color = "cyan")
axis[2].plot(data, ppf1, color = "indigo")

plt.tight_layout() #ajuste de gráfico en el subplot
plt.show()
